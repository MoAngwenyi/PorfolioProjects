# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df_automobile = pd.read_csv(r"C:\Users\USER\Desktop\EXCEL SHENANIGANS\AutomobileData.csv")
df_automobile.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
for col in df_automobile:
    print("column number: ", col)
    print(df_automobile[col].value_counts())
    print(" ")
# Out:
# column number:  symboling
#  0    67
#  1    54
#  2    32
#  3    27
# -1    22
# -2     3
# Name: symboling, dtype: int64
#
# column number:  normalized-losses
# ?      41
# 161    11
# 91      8
# 150     7
# 128     6
# 134     6
# 104     6
# 95      5
# 102     5
# 103     5
# 94      5
# 85      5
# 65      5
# 168     5
# 74      5
# 148     4
# 93      4
# 106     4
# 118     4
# 122     4
# 115     3
# 83      3
# 125     3
# 137     3
# 101     3
# 154     3
# 153     2
# 113     2
# 129     2
# 192     2
# 108     2
# 194     2
# 110     2
# 119     2
# 89      2
# 188     2
# 81      2
# 158     2
# 164     2
# 197     2
# 87      2
# 145     2
# 186     1
# 231     1
# 98      1
# 78      1
# 77      1
# 90      1
# 256     1
# 121     1
# 107     1
# 142     1
# Name: normalized-losses, dtype: int64
#
# column number:  make
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# subaru           12
# ...

# %%
#replace ? with NaN
df_automobile = df_automobile.replace("?", np.NAN)
df_automobile.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romero       gas        std          two
# 1          3               NaN  alfa-romero       gas        std          two
# 2          1               NaN  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
df_automobile.isnull().any().any()
# Out:
# True

# %%
df_automobile.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
avg_norm_loss = df_automobile['normalized-losses'].astype("float").mean()
avg_norm_loss
# Out:
# 122.0

# %%
df_automobile["normalized-losses"].replace(np.NaN, avg_norm_loss, inplace = True)
df_automobile["normalized-losses"]
# Out:
# 0      122.0
# 1      122.0
# 2      122.0
# 3        164
# 4        164
#        ...
# 200       95
# 201       95
# 202       95
# 203       95
# 204       95
# Name: normalized-losses, Length: 205, dtype: object

# %%
avg_bore_loss = df_automobile["bore"].astype("float").mean()
df_automobile["bore"].replace(np.NaN, avg_bore_loss, inplace = True)
df_automobile["bore"]
# Out:
# 0      3.47
# 1      3.47
# 2      2.68
# 3      3.19
# 4      3.19
#        ...
# 200    3.78
# 201    3.78
# 202    3.58
# 203    3.01
# 204    3.78
# Name: bore, Length: 205, dtype: object

# %%
avg_stroke = df_automobile["stroke"].astype("float").mean(axis=0)
print("Average of stroke:", avg_stroke)
df_automobile["stroke"].replace(np.NaN, avg_stroke, inplace= True)
# Out:
# Average of stroke: 3.2554228855721337

# %%
df_automobile.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         2
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           2
# peak-rpm             2
# city-mpg             0
# highway-mpg          0
# price                4
# dtype: int64

# %%
df_automobile["bore"].dtype
# Out:
# dtype('O')

# %%
avg_horsepower = df_automobile["horsepower"].astype("float").mean(axis=0)
print("Average horsepower:", avg_horsepower)
df_automobile["horsepower"].replace(np.NaN, avg_horsepower, inplace=True)
# Out:
# Average horsepower: 104.25615763546799

# %%
avg_peak_rpm = df_automobile["peak-rpm"].astype("float").mean(axis=0)
print("Average peak rpm:", avg_peak_rpm)
df_automobile["peak-rpm"].replace(np.NaN, avg_peak_rpm, inplace=True)
# Out:
# Average peak rpm: 5125.369458128079

# %%
df_automobile["num-of-doors"].value_counts()
# Out:
# four    114
# two      89
# Name: num-of-doors, dtype: int64

# %%
df_automobile["num-of-doors"].value_counts().idxmax()
# Out:
# 'four'

# %%
df_automobile["num-of-doors"].replace(np.NaN, "four", inplace=True)
df_automobile.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3             122.0  alfa-romero       gas        std          two
# 1          3             122.0  alfa-romero       gas        std          two
# 2          1             122.0  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
before_rows = df_automobile.shape[0]
df_automobile.dropna(subset=["price"], axis=0, inplace=True)
after_rows = df_automobile.shape[0]
print("Number of Dropped Rows{}".format(before_rows - after_rows))
df_automobile.reset_index(drop=True, inplace=True)
# Out:
# Number of Dropped Rows4

# %%
df_automobile.shape
# Out:
# (201, 26)

# %%
df_automobile.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
df_automobile[["bore", "stroke"]] = df_automobile[["bore", "stroke"]].astype("float")
df_automobile[["normalized-losses"]] =  df_automobile[["normalized-losses"]].astype("int")
df_automobile[["price"]] = df_automobile[["price"]].astype("float")
df_automobile[["peak-rpm"]] = df_automobile[["peak-rpm"]].astype("float")
df_automobile.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          3                122  alfa-romero       gas        std
# 2          1                122  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
df_automobile["highway-mpg"] = 235/df_automobile["highway-mpg"]
df_automobile.rename(columns = {'highway-mpg':'highway-L/100KM'}, inplace=True)
df_automobile.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          3                122  alfa-romero       gas        std
# 2          1                122  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
df_automobile["length"] = df_automobile["length"]/df_automobile["length"].max()
df_automobile["width"] = df_automobile["width"]/ df_automobile["width"].max()
df_automobile.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          3                122  alfa-romero       gas        std
# 2          1                122  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
df_automobile["height"] = df_automobile["height"]/df_automobile["height"].max()
df_automobile.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          3                122  alfa-romero       gas        std
# 2          1                122  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
df_automobile["horsepower"] = df_automobile["horsepower"].astype(int, copy=True)
df_automobile.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          3                122  alfa-romero       gas        std
# 2          1                122  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.hist(df_automobile["horsepower"])

plt.xlabel("horsepower")
plt.ylabel("counts")
plt.title("horsepower bins")
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %%
bins = np.linspace(min(df_automobile["horsepower"]), max(df_automobile["horsepower"]), 4)
bins
# Out:
# array([ 48.        , 119.33333333, 190.66666667, 262.        ])

# %%
group_names = ['Low', 'Medium', 'High']

# %%
df_automobile['horsepower-binned'] = pd.cut(df_automobile['horsepower'], bins, labels=group_names,include_lowest=True)
df_automobile[['horsepower','horsepower-binned']].head(20)
# Out:
#     horsepower horsepower-binned
# 0          111               Low
# 1          111               Low
# 2          154            Medium
# 3          102               Low
# 4          115               Low
# 5          110               Low
# 6          110               Low
# 7          110               Low
# 8          140            Medium
# 9          101               Low
# 10         101               Low
# 11         121            Medium
# 12         121            Medium
# 13         121            Medium
# 14         182            Medium
# 15         182            Medium
# 16         182            Medium
# 17          48               Low
# 18          70               Low
# 19          70               Low

# %%
df_automobile["horsepower-binned"].value_counts()
# Out:
# Low       153
# Medium     43
# High        5
# Name: horsepower-binned, dtype: int64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.bar(group_names, df_automobile["horsepower-binned"].value_counts())

plt.xlabel("Horsepower")
plt.ylabel("Count")
plt.title("Horsepower Bins")
# Out:
# Text(0.5, 1.0, 'Horsepower Bins')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
a = (0,1,2)
plt.hist(df_automobile["horsepower"], bins=3)

plt.xlabel("horsepower")
plt.ylabel("Count")
plt.title("Horsepower Bins")
plt.show()

# %%
df_automobile.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-L/100KM', 'price', 'horsepower-binned'],
#       dtype='object')

# %%
dummy_variable_1 = pd.get_dummies(df_automobile["fuel-type"])
dummy_variable_1.head()
# Out:
#    diesel  gas
# 0       0    1
# 1       0    1
# 2       0    1
# 3       0    1
# 4       0    1

# %%
dummy_variable_1.rename(columns= {'fuel-type-diesel':'gas','fuel-type-diesel':'diesel'}, inplace=True)
dummy_variable_1.head()
# Out:
#    diesel  gas
# 0       0    1
# 1       0    1
# 2       0    1
# 3       0    1
# 4       0    1

# %%
df_automobile = pd.concat([df_automobile, dummy_variable_1], axis=1)

df_automobile.drop("fuel-type", axis=1, inplace=True)

# %%
dummy_variable_2 = pd.get_dummies(df_automobile['aspiration'])
dummy_variable_2.rename(columns={'std':'aspiration-std', 'turbo': 'aspiration-turbo'}, inplace=True)
dummy_variable_2.head()
# Out:
#    aspiration-std  aspiration-turbo
# 0               1                 0
# 1               1                 0
# 2               1                 0
# 3               1                 0
# 4               1                 0

# %%
df_automobile = pd.concat([df_automobile, dummy_variable_2], axis=1)

df_automobile.drop('aspiration', axis = 1, inplace=True)

# %%
df_automobile.head()
# Out:
#    symboling  normalized-losses         make num-of-doors   body-style  \
# 0          3                122  alfa-romero          two  convertible
# 1          3                122  alfa-romero          two  convertible
# 2          1                122  alfa-romero          two    hatchback
# 3          2                164         audi         four        sedan
# 4          2                164         audi         four        sedan
#
#   drive-wheels engine-location  wheel-base    length     width  ...  city-mpg  \
# 0          rwd           front        88.6  0.811148  0.890278  ...        21
# 1          rwd           front        88.6  0.811148  0.890278  ...        21
# 2          rwd           front        94.5  0.822681  0.909722  ...        19
# 3          fwd           front        99.8  0.848630  0.919444  ...        24
# 4          4wd           front        99.4  0.848630  0.922222  ...        18
#
# ...

# %%
df_automobile.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  201.000000          201.00000  201.000000  201.000000  201.000000
# mean     0.840796          122.00000   98.797015    0.837102    0.915126
# std      1.254802           31.99625    6.066366    0.059213    0.029187
# min     -2.000000           65.00000   86.600000    0.678039    0.837500
# 25%      0.000000          101.00000   94.500000    0.801538    0.890278
# 50%      1.000000          122.00000   97.000000    0.832292    0.909722
# 75%      2.000000          137.00000  102.400000    0.881788    0.925000
# max      3.000000          256.00000  120.900000    1.000000    1.000000
#
#            height  curb-weight  engine-size        bore      stroke  ...  \
# count  201.000000   201.000000   201.000000  201.000000  201.000000  ...
# mean     0.899108  2555.666667   126.875622    3.330692    3.256874  ...
# std      0.040933   517.296727    41.546834    0.268072    0.316048  ...
# ...

# %%
df_automobile.to_csv(r"C:\Users\USER\Downloads\clean-automobile.csv")
